# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0,5,11)
y=x**2
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0,0.5,'Y axis')

# %%
plt.plot(x,y,'r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
# Out:
# Text(0.5,1,'Graph Example')

# %%
plt.plot(x,y,'r',label="Example1")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
plt.legend()

# %%
plt.plot(x,y,'r',label="Example1")
plt.plot(y,x,'g',label="Example2")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
plt.legend()

# %%
plt.plot(x,y,'r',label="Example1")
plt.plot(y,x,'g',label="Example2")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
plt.scatter(x**2,y**2)
plt.legend()

# %%
plt.scatter(x**2,y**2)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(x,y,'r',label="Example1")
plt.plot(y,x,'g',label="Example2")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
plt.legend()
plt.savefig('example.png')

# %%
plt.plot(x,y,'r',label="Example1")
plt.plot(y,x,'g',label="Example2")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
plt.legend()
plt.grid(True)
plt.savefig('example.png')

# %%
plt.scatter(x,y,c='r',label="Example1")
plt.plot(y,x,'g',label="Example2")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
plt.legend()
plt.grid(True)

# %%
plt.plot(x,y,'r*',label="Example1")
plt.plot(y,x,'g*',label="Example2")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
plt.legend()
plt.grid(True)

# %%
plt.plot(x,y,'r-',label="Example1")
plt.plot(y,x,'g--',label="Example2")
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph Example")
plt.legend()
plt.grid(True)

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(x,y,'g*-')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*-')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*-')
plt.subplot(2,2,3)
plt.plot(x,y,'r-')
plt.subplot(2,2,4)
plt.plot(x,y,'g*')

# %% [markdown]
# ## Object Oriented Features

# %%
fig=plt.figure()

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y,'b')
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
# Out:
# Text(0.5,1,'Example Graph')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y,'b')
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
axes.grid(True)

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.8,0.8])

axes.scatter(x,y,c='b')
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
axes.grid(True)

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.3,0.3])


axes1.plot(x,y,'b')
axes1.set_xlabel("X label 1")
axes1.set_ylabel("Y label 1")
axes1.set_title("Example Graph1")


axes2.plot(y,x,'r')
axes2.set_xlabel("X label 2")
axes2.set_ylabel("Y label 2")
axes2.set_title("Example Graph2")
# Out:
# Text(0.5,1,'Example Graph2')

# %%
fig, axes=plt.subplots()

# %%
fig, axes=plt.subplots()

axes.plot(x,y,'b')
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
# Out:
# Text(0.5,1,'Example Graph')

# %%
fig, axes=plt.subplots(1,2)

# %%
fig

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000019E175B3160>,
# ...
#       dtype=object)

# %%
fig, axes=plt.subplots(1,2)
n=0
for ax in axes:
    n=n+1
    ax.plot(x,y,'b')
    ax.set_xlabel('x'+str(n))
    ax.set_ylabel('y'+str(n))
    ax.set_title('Title'+str(n))

# %%
fig=plt.figure(figsize=(8,4),dpi=100)

# %%
fig=plt.figure(figsize=(8,4),dpi=100)
axes=fig.add_axes([0,0,1,1])
axes.plot(x,y,'b')
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
# Out:
# Text(0.5,1,'Example Graph')

# %%
fig, axes=plt.subplots(figsize=(12,3),dpi=100)
axes.plot(x,y,'b')
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
# Out:
# Text(0.5,1,'Example Graph')

# %%
fig, axes=plt.subplots(figsize=(12,3),dpi=1000)
axes.plot(x,y,'b')
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
# Out:
# Text(0.5,1,'Example Graph')

# %%
fig, axes=plt.subplots(figsize=(12,3),dpi=10)
axes.plot(x,y,'b')
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
# Out:
# Text(0.5,1,'Example Graph')

# %%
fig, axes=plt.subplots(figsize=(12,3),dpi=100)
axes.plot(x,y,'b',label="Test")
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
axes.legend()

# %%
fig, axes=plt.subplots(figsize=(12,3),dpi=100)
axes.plot(x,y,'b',label="Test")
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Example Graph")
axes.legend(loc=1)

# %%
fig, ax=plt.subplots()

ax.plot(x,x+1,'b',alpha=0.1) #Alpha is for transparancy
ax.plot(x,x+2,'#880088')
ax.plot(x,x+3,'r')

# %%
fig, ax=plt.subplots()

ax.plot(x,x+1,'b',alpha=0.1) #Alpha is for transparancy
ax.plot(x,x+2,'#880088')
ax.plot(x,x+3,'r')
ax.set_ylim([-5,20])
ax.set_xlim([-5,10])
# Out:
# (-5, 10)

# %%
from random import sample
data = sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([10., 10.,  7.,  8., 11.,  9.,  8., 12., 13., 12.]),
#  array([  7. , 106.1, 205.2, 304.3, 403.4, 502.5, 601.6, 700.7, 799.8,
#         898.9, 998. ]),
#  <a list of 10 Patch objects>)

# %%
data = sample(range(1,1000),100)
plt.hist(data,bins=20)
# Out:
# (array([6., 5., 5., 5., 5., 4., 4., 6., 5., 7., 3., 5., 3., 3., 8., 5., 3.,
#         7., 5., 6.]),
#  array([  2.  ,  51.75, 101.5 , 151.25, 201.  , 250.75, 300.5 , 350.25,
#         400.  , 449.75, 499.5 , 549.25, 599.  , 648.75, 698.5 , 748.25,
#         798.  , 847.75, 897.5 , 947.25, 997.  ]),
#  <a list of 20 Patch objects>)

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips') #inbuild data set

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(tips['total_bill'],hist=False)

# %%
sns.distplot(tips['total_bill'],hist=True,kde=False)
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(tips['total_bill'],bins=20)
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='resid')
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex',palette='coolwarm')

# %%
sns.pairplot(tips,hue='smoker',palette='coolwarm')

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.rugplot(tips['total_bill'])
sns.kdeplot(tips['total_bill'])

# %%
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,palette='rainbow')

# %%
g=sns.PairGrid(tips)
g.map(plt.scatter)

# %%
#get data from iris dataset like tips

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
house = pd.read_csv("C:\\Users\\manoj\\Documents\\Acadgild DSB\\Kaggle Project\\House Sales in King County\\Data\\kc_house_data.csv",parse_dates=["date"])

# %%
house.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
del house["id"]

# %%
house[house["bedrooms"]>30]
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 15870 2014-06-25  640000.0        33       1.75         1620      6000
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 15870     1.0           0     0          5      7        1040            580
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 15870      1947             0    98103  47.6878 -122.331           1330
#
#        sqft_lot15
# 15870        4700

# %%
house[house["sqft_living"]==0]
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []

# %%
fig = plt.figure(figsize=(15, 12))

# loop over all vars (total: 34)
for i in range(1, house.shape[1]):
    plt.subplot(6, 6, i)
    f = plt.gca()
       
    vals = np.size(house.iloc[:, i].unique())
    if vals < 10:
        bins = vals
    else:
        vals = 10

    plt.hist(house.iloc[:, i], bins=30, color='#3F5D7D')
    plt.xlabel(house.columns[i]) 
plt.tight_layout()

# %%
house[house["price"] == 7700000]
# Out:
#            date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 7252 2014-10-13  7700000.0         6        8.0        12050     27600
#
#       floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 7252     2.5           0     3          4     13        8570           3480
#
#       yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 7252      1910          1987    98102  47.6298 -122.323           3940
#
#       sqft_lot15
# 7252        8800

# %%
house[house["sqft_living"]>8000]
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 1164  2014-10-20  5110800.0         5       5.25         8010     45517
# 3914  2014-06-11  7062500.0         5       4.50        10040     37325
# 4411  2014-08-04  5570000.0         5       5.75         9200     35069
# 7252  2014-10-13  7700000.0         6       8.00        12050     27600
# 8092  2014-06-17  4668000.0         5       6.75         9640     13068
# 9254  2014-09-19  6885000.0         6       7.75         9890     31374
# 12777 2014-05-05  2280000.0         7       8.00        13540    307752
# 14556 2014-06-11  2888000.0         5       6.25         8670     64033
# 18302 2014-07-02  3300000.0         5       6.25         8020     21738
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 1164      2.0           1     4          3     12        5990           2020
# 3914      2.0           1     2          3     11        7680           2360
# ...

# %%
fig, ax = plt.subplots(nrows=20, ncols=1, figsize=(6, 160))
i=0 
for col in house.drop('date', axis=1).columns:
    #print(col)
    sns.distplot(house[col], ax= ax[i])
    i += 1

# %%
fig, ax = plt.subplots(nrows=20, ncols=1, figsize=(8, 120))
i=0 
for col in house.drop('price', axis=1).columns:
    #print(col)
    sns.scatterplot(house[col], house['price'], ax= ax[i])
    i += 1

# %%
fig = plt.figure(figsize=(15,12))
sns.heatmap(house.corr(), annot=True, cmap='coolwarm')

# %%
correlation=house.corr()['price'].sort_values()
print("Most positive correltion: \n\n\n", correlation.tail(15))
print("Most negative correltion: \n", correlation.head(15))
# Out:
# Most positive correltion:
#
#
#  sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64
# Most negative correltion:
#  zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# Name: price, dtype: float64

# %%
house["bedrooms"].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
house["bedrooms"].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 8       13
# 0       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
house.groupby("bedrooms")["price"].describe()
# Out:
#            count          mean            std       min        25%       50%  \
# bedrooms
# 0           13.0  4.095038e+05  358682.627507  139950.0  235000.00  288000.0
# 1          199.0  3.176429e+05  148864.955017   75000.0  222000.00  299000.0
# 2         2760.0  4.013727e+05  198051.827269   78000.0  269837.50  374000.0
# 3         9824.0  4.662321e+05  262469.771863   82000.0  295487.50  413000.0
# 4         6882.0  6.354195e+05  388594.441911  100000.0  376962.50  549997.5
# 5         1601.0  7.865998e+05  596204.003693  133000.0  438000.00  620000.0
# 6          272.0  8.255206e+05  799238.819958  175000.0  435000.00  650000.0
# 7           38.0  9.511847e+05  739953.558961  280000.0  539250.00  728580.0
# 8           13.0  1.105077e+06  897495.725295  340000.0  490000.00  700000.0
# 9            6.0  8.939998e+05  381533.900984  450000.0  624999.25  817000.0
# 10           3.0  8.193333e+05  284677.595419  650000.0  655000.00  660000.0
# ...

# %%
house[house["bedrooms"]==33]
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 15870 2014-06-25  640000.0        33       1.75         1620      6000
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 15870     1.0           0     0          5      7        1040            580
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 15870      1947             0    98103  47.6878 -122.331           1330
#
#        sqft_lot15
# 15870        4700

# %%
house[house["floors"]==1]["price"].describe()
# Out:
# count    1.068000e+04
# mean     4.421806e+05
# std      2.640032e+05
# min      7.500000e+04
# 25%      2.750000e+05
# 50%      3.900000e+05
# 75%      5.300000e+05
# max      4.668000e+06
# Name: price, dtype: float64

# %%
import sqlite3 as db
from pandasql import sqldf

# %%
conn = db.connect("sqladb.db")

# %%
house.to_sql("house", conn, if_exists="replace",index=False)

# %%
sql1="""
select * 
from house
where
floors = 1
and grade = 7
and zipcode = 98103
and sqft_living between 1500 and 1800
and sqft_lot between 5000 and 7000
and sqft_above between 900 and 1200
"""

pd.read_sql_query(sql1, conn)
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-07-30 00:00:00  715000.0         3       2.00         1760      5400
# 1  2014-12-03 00:00:00  601150.0         2       2.00         1660      5200
# 2  2014-07-09 00:00:00  680000.0         3       2.00         1780      5720
# 3  2015-05-03 00:00:00  577500.0         2       1.00         1640      5515
# 4  2014-06-23 00:00:00  471001.0         3       1.75         1800      6000
# 5  2014-08-26 00:00:00  549000.0         3       2.00         1560      5130
# 6  2014-06-25 00:00:00  640000.0        33       1.75         1620      6000
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          5      7        1160            600
# 1     1.0           0     0          5      7        1120            540
# 2     1.0           0     0          5      7         980            800
# ...

# %%
house[house["bedrooms"]==33]["bedrooms"]
# Out:
# 15870    33
# Name: bedrooms, dtype: int64

# %%
house.loc[15870,"bedrooms"] = 3

# %%
#house[house.bedrooms ==33].bedrooms.value = 3

# %%
house[house["bedrooms"]==11]
# Out:
#            date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 8757 2014-08-21  520000.0        11        3.0         3000      4960     2.0
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 8757           0     0          3      7        2400            600      1918
#
#       yr_renovated  zipcode     lat     long  sqft_living15  sqft_lot15
# 8757          1999    98106  47.556 -122.363           1420        4960

# %%
sql1="""
select * 
from house
where
floors = 2
and grade = 7
and sqft_living between 2800 and 3200
and sqft_above between 2200 and 2600
"""

pd.read_sql_query(sql1, conn)
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-10-30 00:00:00  669950.0         5       2.50         2820     14062
# 1  2014-09-16 00:00:00  350000.0         3       2.75         3070      5280
# 2  2014-12-23 00:00:00  540000.0         6       3.00         2870    206474
# 3  2014-10-10 00:00:00  409000.0         4       3.25         3140     10752
# 4  2014-06-23 00:00:00  495000.0         3       2.00         2950     12196
# 5  2014-08-21 00:00:00  520000.0        11       3.00         3000      4960
# 6  2014-07-25 00:00:00  540000.0         4       1.50         2993     19400
# 7  2014-07-23 00:00:00  748000.0         4       2.50         3170      4979
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     2.0           0     0          4      7        2380            440
# 1     2.0           0     1          3      7        2360            710
# ...

# %%
sql1="""
select avg(bedrooms)
from house
where
floors = 2
and grade = 7
and sqft_living between 2800 and 3200
and sqft_above between 2200 and 2600
and bedrooms < 11
"""

pd.read_sql_query(sql1, conn)
# Out:
#    avg(bedrooms)
# 0       4.142857

# %%
house[house["bedrooms"]==11]["bedrooms"]
# Out:
# 8757    11
# Name: bedrooms, dtype: int64

# %%
house.loc[8757,"bedrooms"] = 4

# %%
del house["date"]

# %%
#Train and Test split
from sklearn.cross_validation import train_test_split
y=house['price']
x=house.drop(columns=["price"])
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20)
train_x.shape,test_x.shape,train_y.shape,test_y.shape
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# ((17290, 18), (4323, 18), (17290,), (4323,))

# %%
from sklearn.linear_model import LinearRegression
model1=LinearRegression()
model1.fit(train_x,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model1.score(train_x,train_y)
# Out:
# 0.7014655035177748

# %%
model1.score(test_x,test_y)
# Out:
# 0.6927520318678839

# %%
y_pred=model1.predict(test_x)
sns.distplot(y_pred-test_y)

# %%
plt.scatter(y_pred,test_y)

# %%
coeff_df = pd.DataFrame(model1.coef_,x.columns,columns=['Coefficient'])
coeff_df
# Out:
#                  Coefficient
# bedrooms       -40197.386103
# bathrooms       43449.443862
# sqft_living       113.101770
# sqft_lot            0.115208
# floors           7013.130571
# waterfront     630931.172160
# view            54184.559828
# condition       27885.689847
# grade           94526.199608
# sqft_above         72.904279
# sqft_basement      40.197491
# yr_built        -2608.439449
# yr_renovated       17.914444
# zipcode          -570.593921
# lat            610056.304783
# long          -214507.253186
# sqft_living15      21.646814
# sqft_lot15         -0.378225

# %%
from sklearn.metrics import r2_score
r2_score(test_y,y_pred)
# Out:
# 0.6927520318678839

# %%
#Train and Test split
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

y=house['price']
x=house.drop(columns=["price"])
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20)
train_x.shape,test_x.shape,train_y.shape,test_y.shape

model1=LinearRegression()
model1.fit(train_x,train_y)
print("Training Score --> ",model1.score(train_x,train_y))
print("Test Score --> ",model1.score(test_x,test_y))
y_pred=model1.predict(test_x)

print("r2 Score --> ",r2_score(test_y,y_pred))
# Out:
# Training Score -->  0.7045855914268279
# Test Score -->  0.683041231450837
# r2 Score -->  0.683041231450837

# %%
sns.distplot(house["sqft_living"])

# %%
house[house["sqft_lot"]>10000]
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      1225000.0         4       4.50         5420    101930     1.0
# 12      310000.0         3       1.00         1430     19901     1.5
# 16      395000.0         3       2.00         1890     14040     2.0
# 21     2000000.0         3       2.75         3050     44867     1.0
# 36      550000.0         4       1.00         1660     34848     1.0
# 41      775000.0         4       2.25         4220     24186     1.0
# 45      488000.0         3       2.50         3160     13603     2.0
# 47      785000.0         4       2.50         2290     13416     2.0
# 49     1350000.0         3       2.50         2753     65005     1.0
# 58      951000.0         5       3.25         3250     14342     2.0
# 60      650000.0         3       2.25         2150     21235     1.0
# 66      975000.0         4       2.50         2720     11049     2.0
# 68      204000.0         3       1.00         1000     12070     1.0
# ...

# %%
#Train and Test split
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

y=house['price']
x=house.drop(columns=["price","sqft_lot","long"])
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20)
train_x.shape,test_x.shape,train_y.shape,test_y.shape

model1=LinearRegression()
model1.fit(train_x,train_y)
print("Training Score --> ",model1.score(train_x,train_y))
print("Test Score --> ",model1.score(test_x,test_y))
y_pred=model1.predict(test_x)

print("r2 Score --> ",r2_score(test_y,y_pred))
# Out:
# Training Score -->  0.6976435730120754
# Test Score -->  0.6913288475637244
# r2 Score -->  0.6913288475637244

# %%
house["grade"].value_counts()
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
house["age"] = 2018-max(house["yr_built"],house["yr_renovated"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-779746205806> in <module>()
# ----> 1 house["age"] = 2018-max(house["yr_built"],house["yr_renovated"])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1571         raise ValueError("The truth value of a {0} is ambiguous. "
#    1572                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1573                          .format(self.__class__.__name__))
#    1574
#    1575     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
min(2,3)
# Out:
# 2

# %%
house["age"] = 2018- np.where(house["yr_renovated"]==0,house["yr_built"],house["yr_renovated"])

# %%
house[["age","yr_renovated","yr_built"]]
# Out:
#        age  yr_renovated  yr_built
# 0       63             0      1955
# 1       27          1991      1951
# 2       85             0      1933
# 3       53             0      1965
# 4       31             0      1987
# 5       17             0      2001
# 6       23             0      1995
# 7       55             0      1963
# 8       58             0      1960
# 9       15             0      2003
# 10      53             0      1965
# 11      76             0      1942
# 12      91             0      1927
# 13      41             0      1977
# 14     118             0      1900
# 15      39             0      1979
# 16      24             0      1994
# 17     102             0      1916
# 18      97             0      1921
# 19      49             0      1969
# 20      71             0      1947
# 21      50             0      1968
# 22      23             0      1995
# 23      33             0      1985
# 24      33             0      1985
# 25      77             0      1941
# ...

# %%
#Train and Test split
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

y=house['price']
x=house.drop(columns=["price","yr_built","yr_renovated"])
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20)
train_x.shape,test_x.shape,train_y.shape,test_y.shape

model1=LinearRegression()
model1.fit(train_x,train_y)
print("Training Score --> ",model1.score(train_x,train_y))
print("Test Score --> ",model1.score(test_x,test_y))
y_pred=model1.predict(test_x)

print("r2 Score --> ",r2_score(test_y,y_pred))
# Out:
# Training Score -->  0.6865707111544124
# Test Score -->  0.7036733182513897
# r2 Score -->  0.7036733182513897

# %%
house1 = pd.get_dummies(house['zipcode'].astype(str))

# %%
house2=pd.concat([house.drop(columns=["zipcode"]),house1],axis=1)

# %%
house2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 89 columns):
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# age              21613 non-null int64
# 98001            21613 non-null uint8
# 98002            21613 non-null uint8
# ...

# %%
del house2["yr_built"]
del house2["yr_renovated"]

# %%
#Train and Test split
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

y=house2['price']
x=house2.drop(columns=["price"])
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20)
train_x.shape,test_x.shape,train_y.shape,test_y.shape

model1=LinearRegression()
model1.fit(train_x,train_y)
print("Training Score --> ",model1.score(train_x,train_y))
print("Test Score --> ",model1.score(test_x,test_y))
y_pred=model1.predict(test_x)

print("r2 Score --> ",r2_score(test_y,y_pred))
# Out:
# Training Score -->  0.8094739161567788
# Test Score -->  0.7960309233363075
# r2 Score -->  0.7960309233363075

# %%
from sklearn import preprocessing

x = house2.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
house3 = pd.DataFrame(x_scaled)

# %%
#Train and Test split
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

y=house3[0]
x=house3.drop(columns=[0])
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=0.20)
train_x.shape,test_x.shape,train_y.shape,test_y.shape

model1=LinearRegression()
model1.fit(train_x,train_y)
print("Training Score --> ",model1.score(train_x,train_y))
print("Test Score --> ",model1.score(test_x,test_y))
y_pred=model1.predict(test_x)

print("r2 Score --> ",r2_score(test_y,y_pred))
# Out:
# Training Score -->  0.8085777751292469
# Test Score -->  0.7982147349132989
# r2 Score -->  0.798214734913299

# %%
house.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# age              21613 non-null int64
# dtypes: float64(5), int64(15)
# memory usage: 3.3 MB

# %%
house.drop(["sqft_living","sqft_lot"],axis=1,inplace=True)

# %%
house.drop(["lat","long"],axis=1,inplace=True)

# %%
house.drop(["yr_built","yr_renovated"],axis=1,inplace=True)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 14 columns):
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# zipcode          21613 non-null int64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# age              21613 non-null int64
# dtypes: float64(3), int64(11)
# memory usage: 2.3 MB

# %%
house["price_per_sqft"] = house["price"]/(house2["sqft_lot"]+

# %%
house[["sqft_living15","sqft_above","sqft_basement"]]
# Out:
#        sqft_living15  sqft_above  sqft_basement
# 0               1340        1180              0
# 1               1690        2170            400
# 2               2720         770              0
# 3               1360        1050            910
# 4               1800        1680              0
# 5               4760        3890           1530
# 6               2238        1715              0
# 7               1650        1060              0
# 8               1780        1050            730
# 9               2390        1890              0
# 10              2210        1860           1700
# 11              1330         860            300
# 12              1780        1430              0
# 13              1370        1370              0
# 14              1360        1810              0
# 15              2140        1980            970
# 16              1890        1890              0
# 17              1610        1600              0
# 18              1060        1200              0
# ...

# %%
#Train and Test split
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# Out:
# Training Score -->  0.6382241511887901
# Test Score -->  0.6455494309205054
# r2 Score -->  0.6455494309205054

# %%
import modin.pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7e7b44bd7fd7> in <module>()
# ----> 1 import modin.pandas as pd
#
# ModuleNotFoundError: No module named 'modin'
